# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import sys
import os

# %% [markdown]
# ## Root directory

# %%
os.chdir('/research/peer/fdeckert/FD20200109SPLENO')

# %% [markdown]
# # Merge BAM files

# %%
# %%bash
# module load SAMtools

# meta_csv="/research/peer/fdeckert/FD20200109SPLENO/data/bulkRNAseq/object/meta.csv"
# output_dir="/research/peer/fdeckert/FD20200109SPLENO/data/bulkRNAseq/bamcoverage/dpi"

# genotypes=("IFNAR_fl" "IFNAR_fl_LysM_cre")
# celltypes=("cMo" "PreRPM" "RPM" "EB")
# dpis=("D0" "D1" "D3" "D6")

# for genotype in "${genotypes[@]}"; do
#   for celltype in "${celltypes[@]}"; do
#     for dpi in "${dpis[@]}"; do

#       bam_list=($(awk -F, -v g="$genotype" -v c="$celltype" -v d="$dpi" '
#       BEGIN { OFS="," }
#         NR > 1 {
#           gsub(/^"|"$/, "", $5);   # dpi
#           gsub(/^"|"$/, "", $3);   # celltype
#           gsub(/^"|"$/, "", $6);   # genotype
#           gsub(/^"|"$/, "", $8);   # bam_path
#           if ($6 == g && $3 == c && $5 == d) print $8
#         }' "$meta_csv"))
                                                                
#       if [ "${#bam_list[@]}" -gt 0 ]; then
                                                                
#         output_path="$output_dir/${genotype}_${celltype}_${dpi}.bam"                                          
                                                                
#         samtools merge -f "$output_path" "${bam_list[@]}" -@ 32
#         samtools index "$output_path" -@ 32
#       fi

#     done
#   done
# done

# %%
# %%bash
# module load deepTools

# # Set working directory
# cd /research/peer/fdeckert/FD20200109SPLENO/data/bulkRNAseq/bamcoverage/dpi/

# # BAM coverage BigWig
# bamCoverage -b IFNAR_fl_RPM_D0.bam -o IFNAR_fl_RPM_D0.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_RPM_D1.bam -o IFNAR_fl_RPM_D1.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_RPM_D3.bam -o IFNAR_fl_RPM_D3.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_RPM_D6.bam -o IFNAR_fl_RPM_D6.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32

# bamCoverage -b IFNAR_fl_LysM_cre_RPM_D0.bam -o IFNAR_fl_LysM_cre_RPM_D0.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_LysM_cre_RPM_D1.bam -o IFNAR_fl_LysM_cre_RPM_D1.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_LysM_cre_RPM_D3.bam -o IFNAR_fl_LysM_cre_RPM_D3.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32
# bamCoverage -b IFNAR_fl_LysM_cre_RPM_D6.bam -o IFNAR_fl_LysM_cre_RPM_D6.bw --normalizeUsing CPM --binSize 10 --smoothLength 20 --effectiveGenomeSize 2150570000 -p 32

# %%
# %%bash 

# cd /research/peer/fdeckert/FD20200109SPLENO/data/bulkRNAseq/bamcoverage/dpi/

# zcat /research/peer/fdeckert/reference/genome/GRCm39/gencode.vM33.annotation.gtf.gz | \
# awk '$3 == "exon" && $0 ~ /gene_name "Ifnar1"/' | \
# awk -F'\t' '{print $0}' | \
# awk 'BEGIN{OFS="\t"} {print $1, $4-1, $5, $9}' | \
# awk 'NR==3' > ifnar1_exon_3.bed

# %%
# %%bash
# module load deepTools
# module load BEDTools
#
# # Set working directory
# cd /research/peer/fdeckert/FD20200109SPLENO/result/bamcoverage/bulkRNAseq/dpi/
#
# # Visualization tracks
# /nobackup/peer/fdeckert/miniconda3/envs/p.3.10.16-FD20200109SPLENO/bin/pyGenomeTracks --tracks track_ifnar1_extend.ini --fontSize 8 --trackLabelFraction 0.1 --dpi 300 --region chr16:91181126-91355329 -o track_ifnar1_extend.pdf
# /nobackup/peer/fdeckert/miniconda3/envs/p.3.10.16-FD20200109SPLENO/bin/pyGenomeTracks --tracks track_ifnar1.ini --fontSize 8 --trackLabelFraction 0.1 --dpi 300 --region chr16:91281126-91305329 -o track_ifnar1.pdf
# /nobackup/peer/fdeckert/miniconda3/envs/p.3.10.16-FD20200109SPLENO/bin/pyGenomeTracks --tracks track_ifna_ifnb.ini --fontSize 8 --trackLabelFraction 0.1 --dpi 300 --region chr4:88390262-88818893 -o track_ifna_ifnb.pdf
# /nobackup/peer/fdeckert/miniconda3/envs/p.3.10.16-FD20200109SPLENO/bin/pyGenomeTracks --tracks track_lyzm2.ini --fontSize 8 --trackLabelFraction 0.1 --dpi 300 --region chr10:117113036-117118426 -o track_lyzm2.pdf
