# %% [markdown]
# # Monocle2 - Progenitor

# %%
library(monocle)
library(stringr)
library(plyr)
library(netbiov)

# %%
# Set working directory to project root
setwd("/research/peer/fdeckert/FD20200109SPLENO")

# %%
# Source files
source("plotting_global.R")

# %% [markdown]
# # Parameter settingsm

# %%
# Seurat files 
so_file <- "data/object/seurat.rds"

# Plotting Theme
ggplot2::theme_set(theme_global_set()) # From project global source()

# %% [markdown]
# # Import Seurat

# %%
so <- readRDS(so_file)

# %% [markdown]
# # Subset data

# %%
so_1 <- subset(so, subset = treatment == "NaCl" & tissue == "Progenitor" & rna_snn_res.0.8 != 19)
so_2 <- subset(so, subset = treatment == "CpG" & tissue == "Progenitor" & rna_snn_res.0.8 != 19)
# Out:
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from rna_umap_ to rnaumap_”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from rna_umap_ to rnaumap_”
