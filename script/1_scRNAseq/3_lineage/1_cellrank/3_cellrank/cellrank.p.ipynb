# %% [markdown]
# # CellRank
#
# [Lange et al., 2022](https://www.nature.com/articles/s41592-021-01346-6)

# %%
import scvelo as scv
import cellrank as cr
import scanpy as sc

import scipy

import numpy as np
import pandas as pd

import os

# %%
import warnings
warnings.simplefilter('ignore')

# %%
sc.set_figure_params(figsize=(5, 5), dpi_save=1200, fontsize=10, frameon=False, color_map='magma')
scv.set_figure_params(figsize=(5, 5), dpi_save=1200, fontsize=10, frameon=False, color_map='magma')

# %%
os.chdir('/research/peer/fdeckert/FD20200109SPLENO')

# %% [markdown]
# # Import data

# %%
adata = sc.read_h5ad('data/scRNAseq/object/pp.h5ad')

# %% [markdown]
# # Workflow functions

# %%
##########################
### Recompute velocity ###
##########################
def re_compute(adata): 
        
        # Get velocity and top likelihood fit genes 
        v_df = adata.var
        v_df = v_df[v_df.velocity_genes]
        v_df = v_df[v_df.fit_likelihood>=0.10]

        v_genes = v_df.index
        
        # Re-compute neighbors on latent space 
        sc.pp.neighbors(adata, n_neighbors=30, n_pcs=None, use_rep='latent')
            
        # Velocity graph (re-compute)
        scv.tl.velocity_graph(adata, gene_subset=v_genes)

        # Velocity pseudotime 
        scv.tl.velocity_pseudotime(adata)
            
        # Terminal and root cells 
        scv.tl.recover_latent_time(adata)
        
        return adata

# %%
##############
### Kernel ###
##############
def kernel_workflow(k_1, k_2, kr_1=1.0, kr_2=1.0): 

    # Set count matrix
    k_1.adata = k_1.adata.raw.to_adata()
    k_2.adata = k_2.adata.raw.to_adata()

    # Set raw 
    k_1.adata.raw = k_1.adata
    k_2.adata.raw = k_2.adata
    
    # Transission matrix
    k_1 = k_1.compute_transition_matrix()
    k_2 = k_2.compute_transition_matrix()
    
    k = kr_1*k_1 + kr_2*k_2
    
    return(k)

# %%
#############
### GPCCA ###
#############
def gpcca_workflow(k, n_components): 
    
    # Coarse-graining transition matrix into macro-states with GPCCA
    g = cr.estimators.GPCCA(k)
    g.compute_schur(n_components=n_components)
    
    return(g)

# %% [markdown]
# # CellRank Erythroid

# %%
from cellrank.kernels import VelocityKernel
vk_0 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_ery_wt_ctl.pickle')
vk_1 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_ery_wt_d6.pickle')
vk_2 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_ery_ifnar_fl.pickle')
vk_3 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_ery_ifnar_fl_lysm_cre.pickle')

from cellrank.kernels import PseudotimeKernel
pk_0 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_ery_wt_ctl.pickle')
pk_1 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_ery_wt_d6.pickle')
pk_2 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_ery_ifnar_fl.pickle')
pk_3 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_ery_ifnar_fl_lysm_cre.pickle')

from cellrank.kernels import ConnectivityKernel
ck_0 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_ery_wt_ctl.pickle')
ck_1 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_ery_wt_d6.pickle')
ck_2 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_ery_ifnar_fl.pickle')
ck_3 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_ery_ifnar_fl_lysm_cre.pickle')

# %% [markdown]
# ## WT Ctl

# %%
compute_0 = False

# %%
if compute_0: 
    
    # Re-compute velocity kernel 
    vk_0 = VelocityKernel(re_compute(vk_0.adata))
    
    # Combine Kernel
    k_0 = kernel_workflow(vk_0, ck_0, 0.5, 0.5)
    k_0.write('data/scRNAseq/object/cellrank/k_0.pickle', write_adata=True)
    
    # Compute GPCCA
    g_0 = gpcca_workflow(k_0, n_components=20)
    g_0.fit(n_states=15, n_cells=20, cluster_key='celltype_low')
    
    # Set Terminal states 
    g_0.set_terminal_states(['MegP', 'Erythroblast_2'])
    
    # Compute fate probabilities 
    g_0.compute_fate_probabilities(solver='gmres')
    
    # Save GPCCA
    g_0.write('data/scRNAseq/object/cellrank/g_ery_wt_ctl.pickle', write_adata=True)
    
else: 
    
    k_0 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_ery_wt_ctl.pickle')
    g_0 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_ery_wt_ctl.pickle')

# %%
ax = sc.pl.umap(adata, alpha=1, edgecolor='none', size=0, show=False)
sc.pl.umap(adata[adata.obs.celltype_low.isin(['MegP', 'MEP', 'Proerythroblast', 'Erythroblast'])], na_color='#7f7f7f', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
sc.pl.umap(k_0.adata, color='celltype_low', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
k_0.plot_projection(color='celltype_low', recompute=True, save='result/cellrank/umap_stream_ery_wt_ctl.svg', size=0, legend_loc='none', density=1.5, max_length=10, integration_direction='both', ax=ax)

# %%
g_0.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_0.plot_macrostates(which='terminal', legend_loc='on data', discrete=False, figsize=(3, 6), size=100)

# %%
g_0.plot_fate_probabilities(same_plot=True, ncols=5, legend_loc='none', cmap='magma', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_0.adata)
sc.pp.log1p(g_0.adata)

# %%
drivers_2 = g_0.compute_lineage_drivers(lineages='MegP', cluster_key='celltype_low', return_drivers=True)
g_0.plot_lineage_drivers('MegP', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %%
drivers_3 = g_0.compute_lineage_drivers(lineages='Erythroblast_2', cluster_key='celltype_low', return_drivers=True)
g_0.plot_lineage_drivers('Erythroblast_2', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %% [markdown]
# ## WT D6

# %%
compute_1 = False

# %%
if compute_1: 
    
    # Re-compute velocity kernel 
    vk_1 = VelocityKernel(re_compute(vk_1.adata))
    
    # Combine Kernel
    k_1 = kernel_workflow(vk_1, ck_1, 0.5, 0.5)
    k_1.write('data/scRNAseq/object/cellrank/k_ery_wt_d6.pickle', write_adata=True)
    
    # Compute GPCCA
    g_1 = gpcca_workflow(k_1, n_components=20)
    g_1.fit(n_states=15, n_cells=20, cluster_key='celltype_low')
    
    # Set Terminal states
    g_1.set_terminal_states(['MegP', 'Erythroblast_5'])
    
    # Compute fate probabilities 
    g_1.compute_fate_probabilities(solver='gmres')
    
    # Save GPCCA
    g_1.write('data/scRNAseq/object/cellrank/g_ery_wt_d6.pickle', write_adata=True)
    
else: 
    
    k_1 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_ery_wt_d6.pickle')
    g_1 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_ery_wt_d6.pickle')

# %%
ax = sc.pl.umap(adata, alpha=1, edgecolor='none', size=0, show=False)
sc.pl.umap(adata[adata.obs.celltype_low.isin(['MegP', 'MEP', 'Proerythroblast', 'Erythroblast'])], na_color='#7f7f7f', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
sc.pl.umap(k_1.adata, color='celltype_low', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
k_1.plot_projection(color='celltype_low', recompute=True, save='result/cellrank/umap_stream_ery_wt_d6.svg', size=0, legend_loc='none', density=1.5, max_length=10, integration_direction='both', ax=ax)

# %%
g_1.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_1.plot_macrostates(which='terminal', legend_loc='on data', discrete=False, figsize=(3, 6), size=100)

# %%
g_1.plot_fate_probabilities(same_plot=True, ncols=5, legend_loc='none', cmap='magma', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_1.adata)
sc.pp.log1p(g_1.adata)

# %%
drivers_2 = g_1.compute_lineage_drivers(lineages='MegP', cluster_key='celltype_low', return_drivers=True)
g_1.plot_lineage_drivers('MegP', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %%
drivers_3 = g_1.compute_lineage_drivers(lineages='Erythroblast_5', cluster_key='celltype_low', return_drivers=True)
g_1.plot_lineage_drivers('Erythroblast_5', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %% [markdown]
# ## IFNAR fl/fl

# %%
compute_2 = False

# %%
if compute_2: 
    
    # Re-compute velocity kernel 
    vk_2 = VelocityKernel(re_compute(vk_2.adata))
    
    # Combine Kernel
    k_2 = kernel_workflow(vk_2, ck_2, 0.5, 0.5)
    k_2.write('data/scRNAseq/object/cellrank/k_ery_ifnar_fl.pickle', write_adata=True)
    
    # Compute GPCCA
    g_2 = gpcca_workflow(k_2, n_components=20)
    g_2.fit(n_states=15, n_cells=20, cluster_key='celltype_low')
    
    # Set Terminal states
    g_2.set_terminal_states(['MegP', 'Erythroblast_1'])
    
    # Compute fate probabilities 
    g_2.compute_fate_probabilities(solver='gmres')
    
    # Save GPCCA
    g_2.write('data/scRNAseq/object/cellrank/g_ery_ifnar_fl.pickle', write_adata=True)
    
else: 
    
    k_2 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_ery_ifnar_fl.pickle')
    g_2 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_ery_ifnar_fl.pickle')

# %%
ax = sc.pl.umap(adata, alpha=1, edgecolor='none', size=0, show=False)
sc.pl.umap(adata[adata.obs.celltype_low.isin(['MegP', 'MEP', 'Proerythroblast', 'Erythroblast'])], na_color='#7f7f7f', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
sc.pl.umap(k_2.adata, color='celltype_low', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
k_2.plot_projection(color='celltype_low', recompute=True, save='result/cellrank/umap_stream_ery_ifnar_fl.svg', size=0, legend_loc='none', density=1.5, max_length=10, integration_direction='both', ax=ax)

# %%
g_2.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_2.plot_macrostates(which='terminal', legend_loc='on data', discrete=False, figsize=(3, 6), size=100)

# %%
g_2.plot_fate_probabilities(same_plot=True, ncols=5, legend_loc='none', cmap='magma', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_2.adata)
sc.pp.log1p(g_2.adata)

# %%
drivers_2 = g_2.compute_lineage_drivers(lineages='MegP', cluster_key='celltype_low', return_drivers=True)
g_2.plot_lineage_drivers('MegP', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %%
drivers_3 = g_2.compute_lineage_drivers(lineages='Erythroblast_1', cluster_key='celltype_low', return_drivers=True)
g_2.plot_lineage_drivers('Erythroblast_1', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %% [markdown]
# ## IFNAR fl/fl LyzM Cre

# %%
compute_3 = False

# %%
if compute_3: 
    
    # Re-compute velocity kernel 
    vk_3 = VelocityKernel(re_compute(vk_3.adata))
    
    # Combine Kernel
    k_3 = kernel_workflow(vk_3, ck_3, 0.5, 0.5)
    k_3.write('data/scRNAseq/object/cellrank/k_ery_ifnar_fl_lysm_cre.pickle', write_adata=True)
    
    # Compute GPCCA
    g_3 = gpcca_workflow(k_3, n_components=20)
    g_3.fit(n_states=15, n_cells=20, cluster_key='celltype_low')
    
    # Set Terminal states
    g_3.set_terminal_states(['MegP', 'Erythroblast_1'])
    
    # Compute fate probabilities 
    g_3.compute_fate_probabilities(solver='gmres')
    
    # Save GPCCA
    g_3.write('data/scRNAseq/object/cellrank/g_ery_ifnar_fl_lysm_cre.pickle', write_adata=True)
    
else: 
    
    k_3 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_ery_ifnar_fl_lysm_cre.pickle')
    g_3 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_ery_ifnar_fl_lysm_cre.pickle')

# %%
ax = sc.pl.umap(adata, alpha=1, edgecolor='none', size=0, show=False)
sc.pl.umap(adata[adata.obs.celltype_low.isin(['MegP', 'MEP', 'Proerythroblast', 'Erythroblast'])], na_color='#7f7f7f', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
sc.pl.umap(k_3.adata, color='celltype_low', alpha=1, size=20, edgecolor='none', legend_loc='none', show=False, ax=ax)
k_3.plot_projection(color='celltype_low', recompute=True, save='result/cellrank/umap_stream_ery_ifnar_fl_lysm_cre.svg', size=0, legend_loc='none', density=1.5, max_length=10, integration_direction='both', ax=ax)

# %%
g_3.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_3.plot_macrostates(which='terminal', legend_loc='on data', discrete=False, figsize=(3, 6), size=100)

# %%
g_3.plot_fate_probabilities(same_plot=True, ncols=5, legend_loc='none', cmap='magma', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_3.adata)
sc.pp.log1p(g_3.adata)

# %%
drivers_2 = g_3.compute_lineage_drivers(lineages='MegP', cluster_key='celltype_low', return_drivers=True)
g_3.plot_lineage_drivers('MegP', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %%
drivers_3 = g_3.compute_lineage_drivers(lineages='Erythroblast_1', cluster_key='celltype_low', return_drivers=True)
g_3.plot_lineage_drivers('Erythroblast_1', n_genes=5, ncols=5, figsize=(15, 6), size=100)

# %% [markdown]
# # CellRank Progenitor

# %%
from cellrank.kernels import VelocityKernel
vk_0 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_p.pickle')
vk_1 = VelocityKernel.read('data/scRNAseq/object/cellrank/kernel/vk_p_vbc.pickle')

from cellrank.kernels import PseudotimeKernel
pk_0 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_p.pickle')
pk_1 = PseudotimeKernel.read('data/scRNAseq/object/cellrank/kernel/pk_p_vbc.pickle')

from cellrank.kernels import ConnectivityKernel
ck_0 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_p.pickle')
ck_1 = ConnectivityKernel.read('data/scRNAseq/object/cellrank/kernel/ck_p_vbc.pickle')

# %%
compute_0 = True

# %%
if compute_0:
    
    # Combine Kernel
    k_0 = kernel_workflow(pk_0, ck_0, 0.5, 0.5)
    k_0.write('data/scRNAseq/object/cellrank/k_p.pickle', write_adata=True)
    
    # Compute GPCCA
    g_0 = gpcca_workflow(k_0, n_components=20)
    g_0.fit(n_states=10, n_cells=20, cluster_key="celltype_low")

    # Set Terminal states
    g_0.set_terminal_states(['MastP', 'NeuP', 'BasoP', 'MegP', 'Proerythroblast_1'], cluster_key='celltype_low')
    
    # Compute fate probabilities 
    g_0.compute_fate_probabilities(solver='gmres')
        
    # Save GPCCA
    g_0.write('data/scRNAseq/object/cellrank/g_p.pickle', write_adata=True)
    
else: 
    
    k_0 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_p.pickle')
    g_0 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_p.pickle')
# Out:
#   0%|          | 0/5 [00:00<?, ?/s]

# %%
g_0.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_0.plot_macrostates(which='terminal', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_0.adata)
sc.pp.log1p(g_0.adata)

# %%
cr.pl.circular_projection(g_0.adata, keys=['celltype_low', 'genotype', 'dpi', 'Cd34', 'Kit', 'Slamf1', 'Itgb7', 'Cdh1', 'Fcer1a', 'Fcgr2b', 'Fcgr3', 'Elane'], legend_loc='right', use_raw=False, size=50, ncols=6, normalize_by_mean=True, lineage_order='optimal')

# %%
pd.DataFrame(g_0.adata.obsm['X_fate_simplex_fwd'], index=g_0.adata.obs_names, columns=["CR_1", "CR_2"]).to_csv('result/cellrank/fate_simplex_fwd_p.csv')

# %% [markdown]
# # Progenitor VBC

# %%
compute_1 = True

# %%
if compute_1:
    
    # # Combine Kernel
    # k_1 = kernel_workflow(pk_1, ck_1, 0.5, 0.5)
    # k_1.write('data/scRNAseq/object/cellrank/k_p_vbc.pickle', write_adata=True)
    
    # # Compute GPCCA
    # g_1 = gpcca_workflow(k_1, n_components=10)
    # g_1.fit(n_states=10, n_cells=50, cluster_key="celltype_low")

    # Set Terminal states
    g_1.set_terminal_states(['MastP', 'NeuP', 'BasoP', 'MegP', 'MEP_1, MEP_2, MEP_4, MEP_5'], cluster_key='celltype_low')
    
    # Compute fate probabilities 
    g_1.compute_fate_probabilities(solver='gmres')
        
    # Save GPCCA
    g_1.write('data/scRNAseq/object/cellrank/g_p.pickle', write_adata=True)
    
else: 
    
    k_1 = cr.kernels.PrecomputedKernel.read('data/scRNAseq/object/cellrank/k_p_vbc.pickle')
    g_1 = cr.estimators.GPCCA.read('data/scRNAseq/object/cellrank/g_p_vbc.pickle')

# %%
g_1.plot_macrostates(which='all', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
g_1.plot_macrostates(which='terminal', discrete=True, legend_loc='on data', figsize=(3, 6), size=100)

# %%
sc.pp.normalize_total(g_1.adata)
sc.pp.log1p(g_1.adata)

# %%
cr.pl.circular_projection(g_1.adata, keys=['celltype_low', 'ct_pseudotime','genotype', 'dpi', 'Cd34', 'Kit', 'Slamf1', 'Itgb7', 'Cdh1', 'Fcer1a', 'Fcgr2b', 'Fcgr3', 'Elane'], legend_loc='right', use_raw=False, size=50, ncols=6, normalize_by_mean=True, lineage_order='optimal')

# %%
pd.DataFrame(g_1.adata.obsm['X_fate_simplex_fwd'], index=g_1.adata.obs_names, columns=["CR_1", "CR_2"]).to_csv('result/cellrank/fate_simplex_fwd_p_vbc.csv')
