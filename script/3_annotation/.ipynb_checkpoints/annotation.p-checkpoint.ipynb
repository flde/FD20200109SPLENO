# %% [markdown]
# # Annotation

# %%
import scanpy as sc

import pandas as pd

import os
import sys

# %%
import warnings
warnings.simplefilter('ignore', category=UserWarning)
warnings.simplefilter('ignore', category=FutureWarning)
warnings.simplefilter('ignore', category=DeprecationWarning)

# %%
# Working directory
os.chdir('/research/peer/fdeckert/FD20200109SPLENO')
# scFacility 
sys.path.append('../scFacility/script/')

# %% [markdown]
# # Parameter and files

# %%
sc.set_figure_params(figsize=(7.5,7.5), dpi=80, frameon=False, facecolor="white")

# %%
# Input SCVI 
adata_file = 'data/object/int.h5ad'

# %% [markdown]
# # Import scanorama integrated data

# %%
# Load adata from sctransform 
adata = sc.read_h5ad(adata_file)
